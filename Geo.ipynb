# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandroLopezDS/Academypublic/blob/main/Geo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Test
import pandas as pd

from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-aae19d6f-a694-42c7-9e77-c7d9bca6f4b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aae19d6f-a694-42c7-9e77-c7d9bca6f4b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test.xml to Test (9).xml

# %%
uploades
# Out:
# {'Test.xml': b'<?xml version="1.0" encoding="UTF-8" ?>\r\n<!--\n Licensed Materials - Property of IBM\n\n IBM Cognos Products: fmmd\n\n (C) Copyright IBM Corp. 2003, 2016\n\n US Government Users Restricted Rights - Use, duplication or disclosure\n restricted by GSA ADP Schedule Contract with IBM Corp.\n-->\r\n<project queryMode="dynamic" xmlns="http://www.developer.cognos.com/schemas/bmt/60/12" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.developer.cognos.com/schemas/bmt/60/12 BMTModelSpecification.xsd">\n\t<name>Commercial Dashboard</name>\n\t<locales>\n\t\t<locale>en</locale>\n\t</locales>\n\t<defaultLocale>en</defaultLocale>\n\t<namespace>\n\t\t<name locale="en">Commercial Dashboard</name>\n\t\t<lastChanged>2021-03-02T16:54:07</lastChanged>\n\t<lastChangedBy>Peffers, Thomas</lastChangedBy><namespace><name locale="en">Data Layer</name><lastChanged>2021-03-02T16:53:09</lastChanged><lastChangedBy>Peffers, Thomas</lastChangedBy><folder><name loc
# ...

# %%
uploades
# Out:
# {'Test.xml': b'<?xml version="1.0" encoding="UTF-8" ?>\r\n<!--\n Licensed Materials - Property of IBM\n\n IBM Cognos Products: fmmd\n\n (C) Copyright IBM Corp. 2003, 2016\n\n US Government Users Restricted Rights - Use, duplication or disclosure\n restricted by GSA ADP Schedule Contract with IBM Corp.\n-->\r\n<project queryMode="dynamic" xmlns="http://www.developer.cognos.com/schemas/bmt/60/12" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.developer.cognos.com/schemas/bmt/60/12 BMTModelSpecification.xsd">\n\t<name>Commercial Dashboard</name>\n\t<locales>\n\t\t<locale>en</locale>\n\t</locales>\n\t<defaultLocale>en</defaultLocale>\n\t<namespace>\n\t\t<name locale="en">Commercial Dashboard</name>\n\t\t<lastChanged>2021-03-02T16:54:07</lastChanged>\n\t<lastChangedBy>Peffers, Thomas</lastChangedBy><namespace><name locale="en">Data Layer</name><lastChanged>2021-03-02T16:53:09</lastChanged><lastChangedBy>Peffers, Thomas</lastChangedBy><folder><name loc
# ...

# %%
from bs4 import BeautifulSoup
infile = open("Test.xml","r")
contents = infile.read()
soup = BeautifulSoup(contents,'xml')
titles = soup.find_all('collationSequenceLevel')
for title in titles:
    print(title.get_text())

# %%
infile
# Out:
# <_io.TextIOWrapper name='Test.xml' mode='r' encoding='UTF-8'>

# %%
from bs4 import BeautifulSoup

# %%
infile = open("Test.xml","r")
contents = infile.read()

# %%
soup = BeautifulSoup(contents,'lxml')

# %%
relationships_FM = soup.find_all("relationship", {"class": "invalid"})

# %%
titles = soup.find_all("project")

# %%
titles
# Out:
# [<project containsdynamiccontent="false" xmlns="http://www.developer.cognos.com/schemas/bmt/60/12" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemalocation="http://www.developer.cognos.com/schemas/bmt/60/12 BMTModelSpecification.xsd">
#  <name>FSL_MILES_Phase2</name>
#  <property name="included" type="hidden">true</property><locales>
#  <locale>en</locale>
#  </locales>
#  <defaultlocale>en</defaultlocale>
# ...

# %%
'Test.xml'
# Out:
# 'Test.xml'

# %%
from xml.dom import minidom

# parse an xml file by name
mydoc = minidom.parse("Test.xml")

items = mydoc.getElementsByTagName('item')
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# <ipython-input-238-3c6488d189ef> in <module>()
#       2
#       3 # parse an xml file by name
# ----> 4 mydoc = minidom.parse("Test.xml")
#       5
#       6 items = mydoc.getElementsByTagName('item')
#
# /usr/lib/python3.7/xml/dom/minidom.py in parse(file, parser, bufsize)
#    1956     if parser is None and not bufsize:
#    1957         from xml.dom import expatbuilder
# -> 1958         return expatbuilder.parse(file)
#    1959     else:
#    1960         from xml.dom import pulldom
#
# /usr/lib/python3.7/xml/dom/expatbuilder.py in parse(file, namespaces)
#     909     if isinstance(file, str):
#     910         with open(file, 'rb') as fp:
# --> 911             result = builder.parseFile(fp)
#     912     else:
#     913         result = builder.parseFile(file)
#
# ...
